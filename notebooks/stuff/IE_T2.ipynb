# %% [markdown]
# # Intervalo de confiaņca para médias (amostras pequenas)

# %% [markdown]
# ## (i)

# %% [markdown]
# ##(ii)

# %% [markdown]
# #(iii)

# %% [markdown]
# ##(iv)

# %% [markdown]
# ##(v)

# %% [markdown]
# # Intervalo de confiança para médias (amostras grandes)

# %% [markdown]
# ## (i)

# %% [markdown]
# ##(ii)

# %% [markdown]
# ##(iii)

# %% [markdown]
# #Intervalo de confiança para proporções

# %% [markdown]
# ## (i)

# %% [markdown]
# ##(ii)
