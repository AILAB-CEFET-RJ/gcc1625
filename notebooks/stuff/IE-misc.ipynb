# %%
require(MASS)
data(Boston)
names(Boston)
# Out:
# Loading required package: MASS
#  [1] "crim"    "zn"      "indus"   "chas"    "nox"     "rm"      "age"
#  [8] "dis"     "rad"     "tax"     "ptratio" "black"   "lstat"   "medv"

# %%
write.csv(Boston, "./Boston.csv", row.names = TRUE)

# %%
patient = 1:15
moonIncidents = c(3.33, 3.67, 2.67, 3.33, 3.33, 3.67, 4.67,
2.67, 6, 4.33, 3.33, 0.67, 1.33, .33, 2)
otherIncidents = c(.27, .59, .32, .19, 1.26, .11, .3, .4, 1.59,
.6, .65, .69, 1.26, .23, .38)
moondata = data.frame(patient, moonIncidents, otherIncidents)

# %%
write.csv(moondata, "./MoonDay.csv", row.names = FALSE)

# %%
c(moonIncidents, otherIncidents)
# Out:
#  [1] 3.33 3.67 2.67 3.33 3.33 3.67 4.67 2.67 6.00 4.33 3.33 0.67 1.33 0.33 2.00
# [16] 0.27 0.59 0.32 0.19 1.26 0.11 0.30 0.40 1.59 0.60 0.65 0.69 1.26 0.23 0.38

# %%
library(haven)
nhanes = read_xpt('https://wwwn.cdc.gov/Nchs/Nhanes/2013-2014/DEMO_H.XPT')
write.csv(nhanes, "./nhanes.csv", row.names = TRUE)

# %%
nhanes
# Out:
#       SEQN  SDDSRVYR RIDSTATR RIAGENDR RIDAGEYR RIDAGEMN RIDRETH1 RIDRETH3
# 1     73557 8        2        1        69       NA       4        4
# 2     73558 8        2        1        54       NA       3        3
# 3     73559 8        2        1        72       NA       3        3
# 4     73560 8        2        1         9       NA       3        3
# 5     73561 8        2        2        73       NA       3        3
# 6     73562 8        2        1        56       NA       1        1
# 7     73563 8        2        1         0        5       3        3
# 8     73564 8        2        2        61       NA       3        3
# 9     73565 8        1        1        42       NA       2        2
# 10    73566 8        2        2        56       NA       3        3
# 11    73567 8        2        1        65       NA       3        3
# 12    73568 8        2        2        26       NA       3        3
# 13    73569 8        1        2         0       10       5        7
# ...
