# %% [markdown]
# # Binomial

# %%
import numpy as np
from scipy.stats import binom
n, p = 5, 0.5
binom.pmf(3, n, p)
# Out:
# 0.31249999999999983

# %%
import numpy as np
from scipy.stats import binom
n, p = 5, 0.5
binom.cdf(2, n, p)
# Out:
# 0.5

# %% [markdown]
# # Geométrica

# %%
from scipy.stats import geom
import matplotlib.pyplot as plt
import numpy as np

#creating an array of values between
#1 to 20 with a difference of 1
x = np.arange(1, 20, 1)

y = geom.pmf(x, 0.5)

plt.plot(x, y, 'bo')
plt.show()

# %% [markdown]
# # Poisson

# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
import numpy as np

#creating an array of values between
#0 to 20 with a difference of 1
x = np.arange(0, 20, 1)

y = poisson.pmf(x, 10, 0)

plt.plot(x, y, 'bo')
plt.show()

# %% [markdown]
# # Exponencial

# %%
from scipy.stats import expon
1 - expon.cdf(x = 6/60, scale = 1/25)
# Out:
# 0.08208499862389884

# %%
from scipy.stats import expon
expon.cdf(x = 3/60, scale = 1/25) - expon.cdf(x = 2/60, scale = 1/25)
# Out:
# 0.14809341164688816

# %%
3/60, 2/60
# Out:
# (0.05, 0.03333333333333333)

# %% [markdown]
# # LogNormal

# %%
pip install nhanes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.9 MB/s eta 0:00:00
# ...

# %%
from nhanes.load import load_NHANES_data, load_NHANES_metadata

data_df = load_NHANES_data(year='2017-2018')
metadata_df = load_NHANES_metadata(year='2017-2018')

# %%
data_df.shape
# Out:
# (8366, 197)

# %%
data_df.columns.sort_values()[:40]
# Out:
# Index(['1StCancerWhatKindWasIt', '60SecHr30SecHr2', '60SecPulse30SecPulse2',
#        'Age1StCancerMcq230ADiagnosed', 'AgeFirstFedFormuladays',
#        'AgeFirstFedMilkdays', 'AgeInMonthsAtScreening0To24Mos',
#        'AgeInYearsAtScreening', 'AgeStartedOtherFoodbeverage',
#        'AgeStartedSmokingCigarettesRegularly', 'AgeStoppedBreastfeedingdays',
#        'AgeStoppedReceivingFormuladays', 'AgeWhenFirstToldYouHadDiabetes',
#        'AgeWhenToldYouHadAStroke', 'AgeWhenToldYouHadHeartAttack',
#        'AlcoholGm_DR1TOT', 'AlcoholGm_DR2TOT', 'AnnualFamilyIncome',
#        'AnnualHouseholdIncome', 'AttendKindergartenThruHighSchool',
#        'AvgCigarettesdayDuringPast30Days', 'BloodCadmiumUgl', 'BloodLeadUgdl',
#        'BloodManganeseUgl', 'BloodMercuryTotalUgl', 'BloodSeleniumUgl',
#        'BodyMassIndexKgm2', 'CarbohydrateGm_DR1TOT', 'CarbohydrateGm_DR2TOT',
#        'CholesterolMg_DR1TOT', 'CholesterolMg_DR2TOT',
# ...

# %%
data_df['URXUMA']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'URXUMA'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-28f8e56a964f> in <cell line: 1>()
# ----> 1 data_df['URXUMA']
#
# ...
