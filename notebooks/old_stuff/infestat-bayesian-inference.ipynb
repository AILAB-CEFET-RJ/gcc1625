# %%
import numpy as np
n, p = 10, .5  # number of trials, probability of each trial
s = np.random.binomial(n, p, 15)
print(s)
# Out:
# [4 3 6 6 7 6 6 7 6 5 5 3 5 4 8]

# %%
[1/6.]*6
# Out:
# [0.16666666666666666,
#  0.16666666666666666,
#  0.16666666666666666,
#  0.16666666666666666,
#  0.16666666666666666,
#  0.16666666666666666]

# %%
np.random.multinomial(20, [1/6.]*6, size=1)
# Out:
# array([[4, 1, 4, 3, 5, 3]])

# %%
np.random.multinomial(20, [1/6, 1/6, 1/6, 0, 0, 3/6], size=1)
# Out:
# array([[4, 5, 4, 0, 0, 7]])

# %%
import numpy as np
import matplotlib.pyplot as plt
s = np.random.dirichlet((2, 1, 1), 20).transpose()
plt.barh(range(20), s[0])
plt.barh(range(20), s[1], left=s[0], color='g')
plt.barh(range(20), s[2], left=s[0]+s[1], color='r')
plt.title("Lengths of Strings")
# Out:
# Text(0.5, 1.0, 'Lengths of Strings')
