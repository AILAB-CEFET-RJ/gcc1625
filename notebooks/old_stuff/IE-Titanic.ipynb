# %% [markdown]
# Vamos estudar outro exemplo de produção de amostra, desta vez com o conjunto de dados Titanic. Esse conjunto de dados registra informações sobre passageiros do Titanic no episódio do naufrágio.

# %%
df_titanic = pd.read_csv('https://raw.githubusercontent.com/MLRG-CEFET-RJ/ml-class/master/datasets/titanic_train.csv')
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df_titanic.shape
# Out:
# (891, 12)

# %%
df_titanic.Age.hist()

# %%
df_titanic_sample = df_titanic.sample(200, replace=True)
df_titanic_sample.Age.hist()

# %%
# Out:
#      0
# 5    6
# 12  13
# 2    3
# 15  16
# 12  13
# 11  12
# 12  13
# 10  11
# 15  16
# 3    4

# %%
df[].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbb436d3090>]],
#       dtype=object)
