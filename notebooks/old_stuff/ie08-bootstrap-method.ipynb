# %%
import pandas as pd

df = pd.read_csv('Employee_Compensation.csv')

df.head()
# Out:
#    Organization Group Code Job Family Code  ... Total Benefits Total Compensation
# 0                        1            1000  ...       27747.13           85281.78
# 1                        1            1000  ...       22216.82           79895.32
# 2                        1            1000  ...       30116.78           93649.71
# 3                        1            1000  ...       40021.45          134237.37
# 4                        1            1000  ...        2428.31            7512.31
#
# [5 rows x 22 columns]

# %%
df.Job.unique()
# Out:
# array(['IS Administrator 1', 'IS Administrator 3', 'IS Trainer-Assistant',
#        'IS Business Analyst-Principal', 'IS Programmer Analyst',
#        'IS Prg Analyst-Principal', 'IS Project Director',
#        'IT Operations Support Admin IV', 'Training Officer',
#        'Accountant III', 'Accountant IV', 'Senior Administrative Analyst',
#        'Pr Administrative Analyst', 'Senior Personnel Analyst',
#        'Principal Personnel Analyst', 'Executive Secretary 3',
#        'Manager II', 'Manager IV', 'Div Director, Adult Probation',
#        'Chief Adult Probation Officer', 'Chief Deputy Adlt Probation Of',
#        'Chief Dep Adlt Prob Of (SFERS)', 'Deputy Probation Officer',
#        'Deputy Probation Officer SFERS', 'Clerk', 'Principal Clerk',
#        'Chief Clerk', 'Clerk Typist', 'Sr Payroll & Personnel Clerk',
#        'Senior Account Clerk', 'Management Assistant',
#        'Sr Community Devl Spc 1', 'Sr Community Dev Spec 2',
# ...

# %%
df.shape
# Out:
# (29808, 22)

# %%
df.loc[(df['Job'] == 'Dentist')].shape
# Out:
# (15, 22)

# %%
df.where('Job', are.equal_to('Mayor'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d8da686f7b09> in <module>()
# ----> 1 df.where('Job', are.equal_to('Mayor'))
#
# NameError: name 'are' is not defined
